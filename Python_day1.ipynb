# %% [markdown]
# <a href="https://colab.research.google.com/github/iam-pritish/BigData_Pandas/blob/main/Python_day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"This is coding Cell"
# Out:
# 'This is coding Cell'

# %%
2 + 2
# Out:
# 4

# %%
2 + 10
3 * 10
# Out:
# 30

# %%
print(2 + 2)
print(3 * 10)
# Out:
# 4
# 30

# %%
# This is comment

# %% [markdown]
# # Heading
# **BOLD**
# 1. one
# 2. two
# 3. three
#
#
# [Here is the more INFO on Markdown](https://www.markdownguide.org/basic-syntax/)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # Advance Jupyter Notebook Usage

# %% [markdown]
# | Symbol | Name | Example | Usage Explanation |
# |--------|------|---------|-------------------|
# |   !    | Shell Command |    ! ls | Execute shell commands directly from the notebook cell, such as listing files.|
# |   %    | Line Magic    | % cd sample_data | Executes a line magic command, affecting only the line it is on, like changing directories.|
# |   %%   | Cell Magic    | %%writefile test.txt | Applies the magic command to the entire cell, such as writing the cell's content to a file.|

# %%
# !ls
# Out:
# sample_data

# %%
# %timeit [i**2 for i in range(100000)] # This timeit command of shell or terminal where it counts how much time it its to execute the oparation
# Out:
# 9.71 ms ± 1.02 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
L = []  #This timeit command of shell or terminal where it counts hoe much time it its to execute the oparation
for n in range(1000): # This is for multiple line of code.
  L.append(n**2)
# Out:
# 75.1 µs ± 702 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
